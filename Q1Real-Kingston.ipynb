# %%
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_gate_map, plot_error_map

from qiskit.circuit import Parameter

from qiskit_ibm_runtime import SamplerV2 as Sampler
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_aer import AerSimulator

from qiskit.transpiler import PassManager
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.transpiler.passes import TrivialLayout, FullAncillaAllocation, EnlargeWithAncilla, ApplyLayout
from qiskit_ibm_runtime.fake_provider import FakeManilaV2
# %matplotlib inline
import numpy as np 
#connect to real backend
service = QiskitRuntimeService(
    channel="", 
    token="",
    instance="",
    name=""
)

real_backend = service.backend("ibm_torino")
noisy_sim = AerSimulator.from_backend(real_backend)
sim = AerSimulator()

target = real_backend.target
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-03-30 08:13:00,379: Loading account with name Research_CVUT-us. Any input 'channel', 'token' or 'url' are ignored.

# %%
#print backend data
print(f"Connected to: {real_backend.name}")
print(f"Number of qubits: {real_backend.num_qubits}")
print(f"Status: {real_backend.status().status_msg}")
# Plot the physical connections (Topology)
plot_gate_map(real_backend)
plt.savefig("Topology_Kingston")
plt.show()

# Plot a heat map of the gate errors across the whole chip
plot_error_map(real_backend)
plt.savefig("ErrmapKingston.png")
plt.show()
# Out:
# Connected to: ibm_fez
# Number of qubits: 156
# Status: active

# %%
N=8
#number of qubits
Ndata=[]
#number of distances
for i in range(1, N):
    Ndata.append(i)
Sdata=[]
#String for saving S values
q=QuantumRegister(8)
c=ClassicalRegister(2)
qc=QuantumCircuit(q,c)
#register definition
initial_layout = [54, 61, 62, 63, 64, 65, 66, 67]
#path definition
pm = generate_preset_pass_manager(
    backend=real_backend, 
    optimization_level=0, 
    initial_layout=initial_layout
)
transpiled_qc = pm.run(qc)
#chsh code
def chsh (qc, q0, q1, c0, c1):

    settings = [
        ("A0B0", [0, -np.pi/4] ),
        ("A0B1", [0, -3*np.pi/4] ),
        ("A1B0", [-np.pi/2, -np.pi/4] ),
        ("A1B1", [-np.pi/2, -3*np.pi/4] )
    ]
    #chsh measurment settings
    chsh_shots = 100000
    
    sim = AerSimulator(method="matrix_product_state") #methods of aersim
    noisy_sim = AerSimulator.from_backend(real_backend)

    q0_angle = Parameter('θ0')
    q1_angle = Parameter('θ2')
    
    qc2= qc.copy()
    qc2.ry(q0_angle, q0)
    qc2.ry(q1_angle, q1)
    qc2.measure(q0, c0)
    qc2.measure(q1, c1)
    #chsh circuit    
    transpiled_qc = pm.run(qc2)
        
    #sampler = Sampler(mode=sim)
    #sampler = Sampler(mode=noisy_sim)
    sampler = Sampler(mode=real_backend)

    pubs = []
    for st in settings:
        pubs.append( (transpiled_qc, st[1], chsh_shots))
    
    job = sampler.run( pubs )
    print("Job ID: " + job.job_id())
    print("Status: "+ job.status())
    result = job.result()
    #Job Data
    results_E=[]

    for sindex in range(len(settings)):
        counts = result[sindex].join_data().get_counts()
        s00 = counts.get('00', 0)
        s11 = counts.get('11', 0)
        e01 = counts.get('01', 0)
        e10 = counts.get('10', 0)

        total = s00 + s11 + e01 + e10
        E = (s00 + s11 - e01 - e10) / total if total > 0 else 0
        results_E.append(E)
        print(E)

    #S value calculation and saving
    S = results_E[0] - results_E[1] + results_E[2] + results_E[3]
    Sdata.append(S)
    print(S)

# %%
#chsh test for given qubit with distance n
def RunCircuit(n):
    qc1=qc.copy()
#-----------------------------------------------------------------------------
    qc1.h(q[0])
    qc1.cx(q[0], q[1])
    for j in range(1, n):
        qc1.swap(q[j], q[j+1])
    chsh(qc1, q[0], q[n], c[0], c[1])
#----------------------------------------------------------------------------------------
    print("Number ", n, " finished")

# %%
#confirm that the code has been started
print("Cominciato")
for i in range (0, 1): #RunCountsetting1
    Sdata=[]
    for m in range(N-1, N): #RunCountSetting2 - set distances to collect data from
        RunCircuit(m)
    #plot graph based on collected data    
    plt.plot(Ndata, Sdata, marker="o")
    plt.title("Hodnota S na základě vzdálenosti qubitů, IBM Marrakesh")
    plt.axhline(y=2, color="red", linestyle="--")
    plt.ylabel("Hodnota S")
    plt.xlabel("Vzdálenost qubitů")
    plt.xticks(np.arange(0, N, 1.0))
    plt.yticks(np.arange(0, 2*np.sqrt(2), 0.4))
    plt.savefig("SchartKingston1Final")
    plt.show()
print("Data: ", Sdata)
# Out:
# Cominciato
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       3 Sdata=[]
#       4 for m in range(N-1, N):
# ----> 5     RunCircuit(m)
#       6 plt.plot(Ndata, Sdata, marker="o")
#       7 plt.title("Hodnota S na základě vzdálenosti qubitů, IBM Marrakesh")
#
# Cell In[26], line 8, in RunCircuit(n)
#       6     for j in range(1, n):
#       7         qc1.swap(q[j], q[j+1])
# ----> 8     chsh(qc1, q[0], q[n], c[0], c[1])
#       9 #----------------------------------------------------------------------------------------
#      10     print("Number ", n, " finished")
#
# Cell In[25], line 30, in chsh(qc, q0, q1, c0, c1)
#      27 chsh_shots = 100000
#      29 sim = AerSimulator(method="matrix_product_state") #methods of aersim
# ---> 30 noisy_sim = AerSimulator.from_backend(real_backend)
#      32 q0_angle = Parameter('θ0')
#      33 q1_angle = Parameter('θ2')
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\backends\aer_simulator.py:868, in AerSimulator.from_backend(cls, backend, **options)
#     863 if "noise_model" not in options:
#     864     # pylint: disable=import-outside-toplevel
#     865     # Avoid cyclic import
#     866     from ..noise.noise_model import NoiseModel
# --> 868     noise_model = NoiseModel.from_backend(backend)
#     869     if not noise_model.is_ideal():
#     870         options["noise_model"] = noise_model
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\noise\noise_model.py:416, in NoiseModel.from_backend(cls, backend, gate_error, readout_error, thermal_relaxation, temperature, gate_lengths, gate_length_units, warnings)
#     414 with catch_warnings():
#     415     filterwarnings("ignore", category=DeprecationWarning, module="qiskit_aer.noise")
# --> 416     gate_errors = basic_device_gate_errors(
#     417         properties,
#     418         gate_error=gate_error,
#     419         thermal_relaxation=thermal_relaxation,
#     420         gate_lengths=gate_lengths,
#     421         gate_length_units=gate_length_units,
#     422         temperature=temperature,
#     423         warnings=warnings,
#     424         target=target,
#     425     )
#     426 for name, qubits, error in gate_errors:
#     427     noise_model.add_quantum_error(error, name, qubits, warnings=warnings)
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\noise\device\models.py:166, in basic_device_gate_errors(properties, gate_error, thermal_relaxation, gate_lengths, gate_length_units, temperature, warnings, target)
#     160     if gate_lengths:
#     161         raise NoiseError(
#     162             "When `target` is supplied, `gate_lengths` option is not allowed."
#     163             "Use `duration` property in target's InstructionProperties instead."
#     164         )
# --> 166     return _basic_device_target_gate_errors(
#     167         target=target,
#     168         gate_error=gate_error,
#     169         thermal_relaxation=thermal_relaxation,
#     170         temperature=temperature,
#     171     )
#     173 # Generate custom gate time dict
#     174 # Units used in the following computation: ns (time), Hz (frequency), mK (temperature).
#     175 custom_times = {}
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\noise\device\models.py:278, in _basic_device_target_gate_errors(target, gate_error, thermal_relaxation, temperature)
#     276 # Get depolarizing error
#     277 if gate_error and inst_prop.error and isinstance(operation, Gate):
# --> 278     depol_error = _device_depolarizing_error(
#     279         qubits=qubits,
#     280         error_param=inst_prop.error,
#     281         relax_error=relax_error,
#     282     )
#     283 # Combine errors
#     284 combined_error = _combine_depol_and_relax_error(depol_error, relax_error)
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\noise\device\models.py:333, in _device_depolarizing_error(qubits, error_param, relax_error)
#     331     if depol_param > max_param:
#     332         depol_param = min(depol_param, max_param)
# --> 333     return depolarizing_error(depol_param, num_qubits)
#     334 return None
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\noise\errors\standard_errors.py:219, in depolarizing_error(param, num_qubits)
#     216 # Generate pauli strings. The order doesn't matter as long
#     217 # as the all identity string is first.
#     218 paulis = [Pauli("".join(tup)) for tup in it.product(["I", "X", "Y", "Z"], repeat=num_qubits)]
# --> 219 return QuantumError(zip(paulis, probs))
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\noise\errors\quantum_error.py:136, in QuantumError.__init__(self, noise_ops)
#     133 self._probs = list(np.array(probs) / total_probs)
#     135 # Convert instructions to circuits
# --> 136 circs = [self._to_circuit(op) for op in ops]
#     138 num_qubits = max(qc.num_qubits for qc in circs)
#     139 self._circs = [self._enlarge_qreg(qc, num_qubits) for qc in circs]
#
# File ~\anaconda3\Lib\site-packages\qiskit_aer\noise\errors\quantum_error.py:180, in QuantumError._to_circuit(cls, op)
#     178 if hasattr(op, "to_instruction"):
#     179     try:
# --> 180         return cls._to_circuit(op.to_instruction())
#     181     except QiskitError as err:
#     182         raise NoiseError(
#     183             f"Fail to convert {op.__class__.__name__} to Instruction."
#     184         ) from err
#
# File ~\anaconda3\Lib\site-packages\qiskit\quantum_info\operators\symplectic\pauli.py:438, in Pauli.to_instruction(self)
#     435 """Convert to Pauli circuit instruction."""
#     436 from math import pi
# --> 438 pauli, phase = self._to_label(
#     439     self.z, self.x, self._phase[0], full_group=False, return_phase=True
#     440 )
#     441 if len(pauli) == 1:
#     442     gate = {"I": IGate(), "X": XGate(), "Y": YGate(), "Z": ZGate()}[pauli]
#
# File ~\anaconda3\Lib\site-packages\qiskit\quantum_info\operators\symplectic\base_pauli.py:507, in BasePauli._to_label(z, x, phase, group_phase, full_group, return_phase)
#     505 index += x
#     506 ascii_label = _TO_LABEL_CHARS[index[::-1]].data.tobytes()
# --> 507 phase = (int(phase) if group_phase else int(phase) - ascii_label.count(b"Y")) % 4
#     508 label = ascii_label.decode("ascii")
#     509 if phase and full_group:
#
# KeyboardInterrupt:

# %% [markdown]
# Data:  [2.721333333333333, 2.6533333333333333, 2.6112, 2.5952, 2.5186666666666664, 2.5044, 2.4142666666666663, 2.3957333333333333, 2.3381333333333334, 2.2558666666666665, 2.2778666666666667]
# Kingston RUN 2

# %% [markdown]
# Data:  [2.721333333333333, 2.6533333333333333, 2.6112, 2.5952, 2.5186666666666664, 2.5044, 2.4142666666666663, 2.3957333333333333, 2.3381333333333334, 2.2558666666666665, 2.2778666666666667] - Kingson RUN 1
